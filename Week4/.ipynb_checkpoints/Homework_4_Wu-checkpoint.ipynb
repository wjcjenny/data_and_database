# %% [markdown]
# #Homework 4: SQL, Pandas, data munging, and loads of fun
#
# These problem sets encompass two separate topics, covered in class over the past few weeks: (1) basic SQL queries in Python and (2) data munging with Pandas.

# %% [markdown]
# ##Problem set 1: SQL
#
# For the first problem set, you'll be connecting to a remote PostgreSQL server and performing SQL queries inside of Python. You'll need to have either the `psycopg2` library or the `pg8000` library installed on your machine. In the cell below, populate the `host`, `username` and `password` fields with the values we shared with you in class. (If you missed this, ask a fellow student for the credentials.) Make sure to run the cell before you proceed.

# %%
import psycopg2

# %%
host = "54.175.211.148"
username = "ledeprogram"
password = "g0nz0"

# %% [markdown]
# The code in the following cell should establish a connection to the remote SQL server, regardless of whether or not you have `pg8000` or `pgsql` installed. The connection object will be assigned to a variable called `conn`. Run this cell before you proceed. (The output of the cell should either be `pg8000.core.Connection` or `psycopg2.extensions.connection`, depending on which library you have installed.)

# %%
try:
    import psycopg2
    conn = psycopg2.connect(host=host, user=username, password=password, database="kittens")
except ImportError:
    import pg8000
    conn = pg8000.connect(host=host, user=username, password=password, database="kittens")
type(conn)
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# <ipython-input-3-d012a0e6614a> in <module>()
#       1 try:
#       2     import psycopg2
# ----> 3     conn = psycopg2.connect(host=host, user=username, password=password, database="kittens")
#       4 except ImportError:
#       5     import pg8000
#
# /Library/Python/2.7/site-packages/psycopg2/__init__.pyc in connect(dsn, database, user, password, host, port, connection_factory, cursor_factory, async, **kwargs)
#     162                 for (k, v) in items])
#     163
# --> 164     conn = _connect(dsn, connection_factory=connection_factory, async=async)
#     165     if cursor_factory is not None:
#     166         conn.cursor_factory = cursor_factory
#
# OperationalError: could not connect to server: Operation timed out
# 	Is the server running on host "54.175.211.148" and accepting
# 	TCP/IP connections on port 5432?

# %% [markdown]
# Okay, now we can get to work! In the cell below, replace the expression `None` with the expression that evaluates to a new cursor object, created from the connection object you established in the cell above. Assign this cursor to a variable called `cursor`.
#
# Expected output: either `<pg8000.core.Cursor instance at ...>` or `<cursor object at ...; closed: 0>`, depending on which library you're using. (The `...` will be a hexadecimal number like `0x12345`. The value will be unique every time you create a new cursor object.)

# %%
cursor = conn.cursor()
cursor

# %% [markdown]
# Great work! You're now connected to a PostgreSQL server (running on a machine in the ~cloud~) that has a database named `kittens`. In this database, there is a single table called `kittens`. The schema of that table looks like this:
#
# ```
#            Table "public.kittens"
#  Column  |         Type          | Modifiers
# ---------+-----------------------+-----------
#  name    | character varying(80) |
#  age     | integer               |
#  weight  | double precision      |
#  borough | character varying(30) |
# ```
#
# In the cell below, I've written the code necessary to make a query to the database. Fill in the value inside the quotation marks so that the output of the cell is a tuple with the values from all four columns in the first row in the database.
#
# Expected output: `('Monsieur Whiskeurs', 5, 12.2, 'Brooklyn')` (this may be a list, not a tuple, if you're using `pg8000` instead of `psycopg2`.)

# %%
cursor.execute("SELECT name,age,weight,borough FROM kittens")
cursor.fetchone()

# %% [markdown]
# Great work! Now, copy the `cursor.execute(...)` line from the cell above and paste it into the cell below. Write the code necessary to print the following output:
#
# ```
# Monsieur Whiskeurs is 5 years old, weighs 12.2 pounds and lives in Brooklyn
# Fluffles McGee is 2 years old, weighs 8.9 pounds and lives in Queens
# Gazpacho is 9 years old, weighs 11.2 pounds and lives in Brooklyn
# William T. Riker is 4 years old, weighs 13.0 pounds and lives in Manhattan
# Princess is 8 years old, weighs 10.2 pounds and lives in Bronx
# Meowchelle, Ma Belle is 13 years old, weighs 9.1 pounds and lives in Brooklyn
# ```
#
# (Hint: to retrieve all rows from a query, use a `for` loop to iterate over the cursor object. You might want to simply `print` each row first to see how the data is arranged.)

# %%
#cursor.execute("write your query here")
cursor.execute("SELECT name, age, weight, borough FROM kittens") 
for row in cursor:
#     print row
#     print row[0]
    print row[0], "is", row[1], "years old, weighs", row[2], "pounds and lives in", row[3]

# %% [markdown]
# Okay, the hard part is over. The following problem is a test of your SQL skills. In the cell below, modify the string inside of `cursor.execute(...)` so that the query returns the names of every cat from Brooklyn that weights more than 10 pounds. Write a `for` loop to print these results.
#
# Expected output:
# ```
# Monsieur Whiskeurs
# Gazpacho
# ```

# %%
cursor.execute("SELECT name FROM kittens WHERE borough ='Brooklyn' AND weight > 10.0")
for row in cursor:
    print row

# %% [markdown]
# ##Problem set 2: Pandas
#
# Remember, you need to import pandas before you can use it. Make the plots inline too!

# %%
# %matplotlib inline

import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
#you need to press enter

# %% [markdown]
# ###Indexing of dataframes
#
# In cells below, import the EduX data set we used in calss from your notebooks directory as a dataframe.
#
# Using `pandas`, slice and dice to get:
# 1. a dataframe with only the User Id and grade columns
# 2. a dataframe with all the columns but only rows 400, 500, 600, 700, 800, 900, 1000, 1100, 1200

# %%
df = pd.read_csv("HMXPC_13.csv")
df
# Out:
#                           course_id       userid_DI  registered  viewed  \
# 0        HarvardX/CB22x/2013_Spring  MHxPC130442623           1       0
# 1               HarvardX/CS50x/2012  MHxPC130442623           1       1
# 2        HarvardX/CB22x/2013_Spring  MHxPC130275857           1       0
# 3               HarvardX/CS50x/2012  MHxPC130275857           1       0
# 4        HarvardX/ER22x/2013_Spring  MHxPC130275857           1       0
# 5         HarvardX/PH207x/2012_Fall  MHxPC130275857           1       1
# 6       HarvardX/PH278x/2013_Spring  MHxPC130275857           1       0
# 7        HarvardX/CB22x/2013_Spring  MHxPC130539455           1       1
# 8        HarvardX/CB22x/2013_Spring  MHxPC130088379           1       1
# 9               HarvardX/CS50x/2012  MHxPC130088379           1       1
# 10       HarvardX/ER22x/2013_Spring  MHxPC130088379           1       1
# 11       HarvardX/ER22x/2013_Spring  MHxPC130198098           1       1
# 12       HarvardX/CB22x/2013_Spring  MHxPC130024894           1       1
# 13              HarvardX/CS50x/2012  MHxPC130024894           1       1
# 14       HarvardX/ER22x/2013_Spring  MHxPC130024894           1       1
# 15        HarvardX/PH207x/2012_Fall  MHxPC130024894           1       1
# 16      HarvardX/PH278x/2013_Spring  MHxPC130024894           1       1
# 17              HarvardX/CS50x/2012  MHxPC130080986           1       1
# 18        HarvardX/PH207x/2012_Fall  MHxPC130080986           1       1
# 19              HarvardX/CS50x/2012  MHxPC130063375           1       1
# 0         2012-12-19    2013-11-17      NaN          9          NaN
# 1         2012-10-15           NaN      NaN          9          NaN
# 2         2013-02-08    2013-11-17      NaN         16          NaN
# 3         2012-09-17           NaN      NaN         16          NaN
# 4         2012-12-19           NaN      NaN         16          NaN
# 5         2012-09-17    2013-05-23      502         16           50
# 6         2013-02-08           NaN      NaN         16          NaN
# 7         2013-01-01    2013-05-14       42          6          NaN
# 8         2013-02-18    2013-03-17       70          3          NaN
# 9         2012-10-20           NaN      NaN         12          NaN
# 10        2013-02-23    2013-06-14       17          2          NaN
# 11        2013-06-17    2013-06-17       32          1          NaN
# 12        2013-01-24    2013-08-03      175          9          NaN
# 13        2013-06-27           NaN      NaN          2          NaN
# 14        2012-12-19    2013-08-17       78          5          NaN
# 15        2012-07-26    2013-01-16       75         14            5
# 16        2013-07-30    2013-08-27       11          2            2
# 17        2012-10-15           NaN      NaN         11          NaN
# 18        2012-10-25    2012-12-04       56         11            1
# 19        2012-10-19           NaN      NaN        NaN          NaN
# 20        2013-03-03    2013-03-03        7          1          NaN
# 21        2012-10-15           NaN      NaN        NaN          NaN
# 22        2012-10-24           NaN      NaN          2          NaN
# 23        2012-12-20    2013-05-18       15          2          NaN
# 24        2012-10-29    2013-03-04        1          1          NaN
# 25        2012-09-04           NaN      NaN        NaN          NaN
# 26        2012-09-05           NaN      NaN        NaN          NaN
# 27        2012-10-22    2013-03-30        6          1          NaN
# 28        2013-01-07           NaN      NaN        NaN          NaN
# 29        2013-02-11    2013-04-06      285          8          NaN
# ...              ...           ...      ...        ...          ...
# 641108    2013-09-07    2013-09-07       59          1            5
# 641109    2013-09-07           NaN      NaN        NaN          NaN
# 641110    2013-09-07    2013-09-07      395          1           51
# 641111    2013-09-07    2013-09-07       49          1           14
# 641112    2013-09-07           NaN      NaN        NaN          NaN
# 641113    2013-09-07    2013-09-07        8          1          NaN
# 641114    2013-09-07    2013-09-07       22          1            5
# 641115    2013-09-07    2013-09-07        2          1          NaN
# 641116    2013-09-07           NaN      NaN        NaN          NaN
# 641117    2013-09-07    2013-09-07        2          1          NaN
# 641118    2013-09-07           NaN      NaN        NaN          NaN
# 641119    2013-09-07    2013-09-07        2          1          NaN
# 641120    2013-09-07    2013-09-07       49          1          NaN
# 641121    2013-09-07           NaN      NaN        NaN          NaN
# 641122    2013-09-07    2013-09-07        1          1          NaN
# 641123    2013-09-07    2013-09-07        1          1          NaN
# 641124    2013-09-07    2013-09-07       59          1          NaN
# 641125    2013-09-07    2013-09-07        2          1          NaN
# 641126    2013-09-07    2013-09-07      251          1           77
# 641127    2013-09-07    2013-09-07        1          1          NaN
# 641128    2013-09-07    2013-09-07       51          1            1
# 641129    2013-09-07           NaN      NaN        NaN          NaN
# 641130    2013-09-07    2013-09-07        6          1          NaN
# 641131    2013-09-07    2013-09-07       11          1          NaN
# 641132    2013-09-07    2013-09-07       29          1          NaN
# 641133    2013-09-07    2013-09-07       97          1            4
# 641134    2013-09-07    2013-09-07        1          1          NaN
# 641135    2013-09-07    2013-09-07        1          1          NaN
# 641136    2013-09-07    2013-09-07       74          1           14
# 641137    2013-09-07           NaN      NaN          1          NaN
#
#         nchapters  nforum_posts  roles  incomplete_flag
# 0             NaN             0    NaN                1
# 1               1             0    NaN                1
# 2             NaN             0    NaN                1
# 3             NaN             0    NaN                1
# 4             NaN             0    NaN                1
# 5              12             0    NaN              NaN
# 6             NaN             0    NaN                1
# 7               3             0    NaN              NaN
# 8               3             0    NaN              NaN
# 9               3             0    NaN                1
# 10              2             0    NaN              NaN
# 11              3             0    NaN              NaN
# 12              7             0    NaN              NaN
# 13              2             0    NaN                1
# 14              4             0    NaN              NaN
# 15              2             0    NaN              NaN
# 16              1             0    NaN              NaN
# 17              1             0    NaN                1
# 18              2             1    NaN              NaN
# 19              1             0    NaN                1
# 20              2             0    NaN              NaN
# 21              1             0    NaN                1
# 22              1             0    NaN                1
# 23              2             0    NaN              NaN
# 24              2             0    NaN              NaN
# 25            NaN             0    NaN              NaN
# 26              3             0    NaN                1
# 27              5             0    NaN              NaN
# 28              1             0    NaN                1
# 29              4             0    NaN              NaN
# ...           ...           ...    ...              ...
# 641108          3             0    NaN              NaN
# 641109          2             0    NaN                1
# 641110          4             0    NaN              NaN
# 641111          2             0    NaN              NaN
# 641112        NaN             0    NaN              NaN
# 641113          1             0    NaN              NaN
# 641114          1             0    NaN              NaN
# 641115          3             0    NaN              NaN
# 641116        NaN             0    NaN              NaN
# 641117          3             0    NaN              NaN
# 641118        NaN             0    NaN              NaN
# 641119          2             0    NaN              NaN
# 641120          1             0    NaN              NaN
# 641121          7             0    NaN                1
# 641122        NaN             0    NaN              NaN
# 641123        NaN             0    NaN              NaN
# 641124          2             0    NaN              NaN
# 641125        NaN             0    NaN              NaN
# 641126          4             0    NaN              NaN
# 641127        NaN             0    NaN              NaN
# 641128          1             0    NaN              NaN
# 641129        NaN             0    NaN              NaN
# 641130        NaN             0    NaN              NaN
# 641131          2             0    NaN              NaN
# 641132          1             0    NaN              NaN
# 641133          2             0    NaN              NaN
# 641134        NaN             0    NaN              NaN
# 641135        NaN             0    NaN              NaN
# 641136          1             0    NaN              NaN
# 641137        NaN             0    NaN                1
#
# [641138 rows x 20 columns]

# %%
df[['userid_DI','grade']]
# Out:
#              userid_DI grade
# 0       MHxPC130442623     0
# 1       MHxPC130442623     0
# 2       MHxPC130275857     0
# 3       MHxPC130275857     0
# 4       MHxPC130275857     0
# 5       MHxPC130275857     0
# 6       MHxPC130275857     0
# 7       MHxPC130539455     0
# 8       MHxPC130088379     0
# 9       MHxPC130088379     0
# 10      MHxPC130088379     0
# 11      MHxPC130198098     0
# 12      MHxPC130024894  0.07
# 13      MHxPC130024894     0
# 14      MHxPC130024894     0
# 15      MHxPC130024894     0
# 16      MHxPC130024894     0
# 17      MHxPC130080986     0
# 18      MHxPC130080986     0
# 19      MHxPC130063375     0
# 20      MHxPC130094371     0
# 21      MHxPC130229084     0
# 22      MHxPC130300925     0
# 23      MHxPC130300925     0
# 24      MHxPC130417650     0
# 25      MHxPC130506580     0
# 26      MHxPC130298257     0
# 27      MHxPC130500569     0
# 28      MHxPC130466479     0
# 29      MHxPC130340959  0.05
# ...                ...   ...
# 641108  MHxPC130140735   NaN
# 641109  MHxPC130493130   NaN
# 641110  MHxPC130400592   NaN
# 641111  MHxPC130109892   NaN
# 641112  MHxPC130183007   NaN
# 641113  MHxPC130261281     0
# 641114  MHxPC130481990   NaN
# 641115  MHxPC130528581   NaN
# 641116  MHxPC130555418   NaN
# 641117  MHxPC130408810   NaN
# 641118  MHxPC130040184   NaN
# 641119  MHxPC130566049   NaN
# 641120  MHxPC130374105     0
# 641121  MHxPC130282999   NaN
# 641122  MHxPC130556398     0
# 641123  MHxPC130573334   NaN
# 641124  MHxPC130505931   NaN
# 641125  MHxPC130280976   NaN
# 641126  MHxPC130137331   NaN
# 641127  MHxPC130271624   NaN
# 641128  MHxPC130256541   NaN
# 641129  MHxPC130021638   NaN
# 641130  MHxPC130591057   NaN
# 641131  MHxPC130226305   NaN
# 641132  MHxPC130030805   NaN
# 641133  MHxPC130184108   NaN
# 641134  MHxPC130359782   NaN
# 641135  MHxPC130098513   NaN
# 641136  MHxPC130098513   NaN
# 641137  MHxPC130098513   NaN
#
# [641138 rows x 2 columns]

# %%
specific_rows = [400, 500, 600, 700, 800, 900, 1000, 1100, 1200]
df.ix[specific_rows]
# Out:
#                        course_id       userid_DI  registered  viewed  \
# 400          HarvardX/CS50x/2012  MHxPC130170796           1       1
# 500          HarvardX/CS50x/2012  MHxPC130112140           1       1
# 600   HarvardX/ER22x/2013_Spring  MHxPC130000623           1       1
# 700          HarvardX/CS50x/2012  MHxPC130576970           1       0
# 800    HarvardX/PH207x/2012_Fall  MHxPC130184766           1       1
# 900          HarvardX/CS50x/2012  MHxPC130560886           1       1
# 1000   HarvardX/PH207x/2012_Fall  MHxPC130427773           1       0
# 1100         HarvardX/CS50x/2012  MHxPC130030276           1       1
# 1200  HarvardX/ER22x/2013_Spring  MHxPC130229078           1       1
#
#       explored  certified final_cc_cname_DI LoE_DI  YoB gender grade  \
# 400          1          0             India    NaN  NaN    NaN     0
# 500          0          0     United States    NaN  NaN    NaN     0
# 600          1          1    United Kingdom    NaN  NaN    NaN  0.84
# 700          0          0     Unknown/Other    NaN  NaN    NaN     0
# 800          0          0           Ukraine    NaN  NaN    NaN     0
# 900          0          0    United Kingdom    NaN  NaN    NaN     0
# 1000         0          0     United States    NaN  NaN    NaN     0
# 1100         1          0            Canada    NaN  NaN    NaN     0
# 1200         0          0     United States    NaN  NaN    NaN   NaN
#
#      start_time_DI last_event_DI  nevents  ndays_act  nplay_video  nchapters  \
# 400     2012-07-24           NaN      NaN        NaN          NaN         12
# 500     2012-08-14    2013-04-09        6          2          NaN          2
# 600     2013-01-08    2013-08-08     2426        118          NaN         29
# 700     2012-08-17           NaN      NaN        NaN          NaN        NaN
# 800     2012-07-26    2012-10-21       89          3           12          2
# 900     2012-07-29    2013-05-19       11          2          NaN          1
# 1000    2012-08-17    2012-08-17        1          1          NaN        NaN
# 1100    2013-02-26    2013-03-26       50          2          NaN          9
# 1200    2012-12-20    2013-03-14        4          1          NaN          1
#
#       nforum_posts  roles  incomplete_flag
# 400              0    NaN                1
# 500              0    NaN              NaN
# 600              0    NaN              NaN
# 700              0    NaN              NaN
# 800              0    NaN              NaN
# 900              0    NaN              NaN
# 1000             0    NaN              NaN
# 1100             0    NaN              NaN
# 1200             0    NaN              NaN

# %% [markdown]
# ###Boolean indexing

# %% [markdown]
# Suppose `happydataframe` is a dataframe with 200 rows and two columns "activity" and "endorphin_level".
#
# In the cell below, explain briefly what is the difference between
#
#     happydataframe["activity"]="philately"
#
#  and
#
#     happydataframe["activity"]=="philalely"

# %% [markdown]
# Using the EduX dataset, compute how much video (`nplay_video`) on average the following watched:
# - women
# - men from Spain
# - woman older than 30 from India
#
# Use boolean indexing.

# %%
df.groupby(['gender']).mean()['nplay_video']

# gender
# f         123.867448
# m         104.073069
# o                NaN
# Name: nplay_video, dtype: float64

# %%
#women
df[(df['gender']=='f')].mean()['nplay_video']

#123.867448

# %%
#men from Spain
df[(df['final_cc_cname_DI'] == 'Spain') &(df['gender'] == 'm')].mean()['nplay_video']

#203.84181415929203

# %%
#woman older than 30 from India
df[(df['final_cc_cname_DI'] == 'India') &(df['gender'] == 'f') & (df['YoB'] < 1985)].mean()['nplay_video']

#197.99380421313506

# %% [markdown]
# Using the `.groupby` method create a data frame of how much video on average people from different countries of different genders watched. You can pass `groupby` a list of columns to group by.
#
# something roughly like:
#
# >India
#
# >       F   10
#
# >       M   20
#
# >France
#
# >       F   300
#
# >       M   10
#
# Precise formatting not at issue

# %%
df.groupby(['final_cc_cname_DI', 'gender']).mean()['nplay_video']

# %% [markdown]
# ##Simple statistical work

# %% [markdown]
# Download a small auto mileage data set from
#
# http://www.columbia.edu/~mj340/auto-mpg.csv. (This is a sample data set included in the `Bokeh` package)
#
# Using this auto mileage data set, find the average mpg (miles per gallon) per year for all cars and plot the values for each year. Include a title on your plot. Use panda's `groupby` function and its .plot() method.

# %%
df2 =pd.read_csv("auto-mpg.csv")
df2
# Out:
#      mpg  cyl  displ   hp  weight  accel  yr  origin  \
# 0     18    8    307  130    3504   12.0  70       1
# 1     15    8    350  165    3693   11.5  70       1
# 2     18    8    318  150    3436   11.0  70       1
# 3     16    8    304  150    3433   12.0  70       1
# 4     17    8    302  140    3449   10.5  70       1
# 5     15    8    429  198    4341   10.0  70       1
# 6     14    8    454  220    4354    9.0  70       1
# 7     14    8    440  215    4312    8.5  70       1
# 8     14    8    455  225    4425   10.0  70       1
# 9     15    8    390  190    3850    8.5  70       1
# 10    15    8    383  170    3563   10.0  70       1
# 11    14    8    340  160    3609    8.0  70       1
# 12    15    8    400  150    3761    9.5  70       1
# 13    14    8    455  225    3086   10.0  70       1
# 14    24    4    113   95    2372   15.0  70       3
# 15    22    6    198   95    2833   15.5  70       1
# 16    18    6    199   97    2774   15.5  70       1
# 17    21    6    200   85    2587   16.0  70       1
# 18    27    4     97   88    2130   14.5  70       3
# 371                   mazda glc custom
# 372             plymouth horizon miser
# 373                     mercury lynx l
# 374                   nissan stanza xe
# 375                       honda accord
# 376                     toyota corolla
# 377                        honda civic
# 378                 honda civic (auto)
# 379                      datsun 310 gx
# 380              buick century limited
# 381  oldsmobile cutlass ciera (diesel)
# 382         chrysler lebaron medallion
# 383                     ford granada l
# 384                   toyota celica gt
# 385                  dodge charger 2.2
# 386                   chevrolet camaro
# 387                    ford mustang gl
# 388                          vw pickup
# 389                      dodge rampage
# 390                        ford ranger
# 391                         chevy s-10
#
# [392 rows x 9 columns]

# %%
cars = df2.groupby(['yr']).mean()['mpg']
cars.plot(kind = "bar", title = "the average mpg (miles per gallon) per year for all cars")

# %% [markdown]
# In the data base design, the manufacturer and car type are in a single string field (Ford Galaxie), rather than splitting the manufacturer (Ford) from the particular model (Galaxie). Using regular expressions or any other technique, separate the manufacturer from the mode and create two new columns for the manufacturer and the car models.
#
# Now:
# 1. Find the average mpg for each manufacturer
# 2. Plot the changing mpg for four manufacturers

# %%
df2['name'][:5]
# Out:
# 0    chevrolet chevelle malibu
# 1            buick skylark 320
# 2           plymouth satellite
# 3                amc rebel sst
# 4                  ford torino
# Name: name, dtype: object

# %%
df2['manufacturer'] = "null"
df2['model'] = "null"

# %%
#for n in df2['name']:
for i in range(len(df2['name'])): 
    df2['manufacturer'][i]= df2['name'][i].split()[0]
    df2['model'][i]=" ".join(df2['name'][i].split()[1:])
# Out:
# /Users/jiachuan/anaconda/lib/python2.7/site-packages/IPython/kernel/__main__.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   app.launch_new_instance()
# /Users/jiachuan/anaconda/lib/python2.7/site-packages/IPython/kernel/__main__.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
df2['manufacturer']
# Out:
# 0     chevrolet
# 1         buick
# 2      plymouth
# 3           amc
# 4          ford
# 5          ford
# 6     chevrolet
# 7      plymouth
# 8       pontiac
# 9           amc
# 10        dodge
# 11     plymouth
# 12    chevrolet
# 13        buick
# 14       toyota
# ...
# 377         honda
# 378         honda
# 379        datsun
# 380         buick
# 381    oldsmobile
# 382      chrysler
# 383          ford
# 384        toyota
# 385         dodge
# 386     chevrolet
# 387          ford
# 388            vw
# 389         dodge
# 390          ford
# 391         chevy
# Name: manufacturer, Length: 392, dtype: object

# %%
df2['model']
# Out:
# 0       chevelle malibu
# 1           skylark 320
# 2             satellite
# 3             rebel sst
# 4                torino
# 5           galaxie 500
# 6                impala
# 7              fury iii
# 8              catalina
# 9        ambassador dpl
# 10        challenger se
# 11            'cuda 340
# 12          monte carlo
# 13    estate wagon (sw)
# 14       corona mark ii
# ...
# 377                     civic
# 378              civic (auto)
# 379                    310 gx
# 380           century limited
# 381    cutlass ciera (diesel)
# 382         lebaron medallion
# 383                 granada l
# 384                 celica gt
# 385               charger 2.2
# 386                    camaro
# 387                mustang gl
# 388                    pickup
# 389                   rampage
# 390                    ranger
# 391                      s-10
# Name: model, Length: 392, dtype: object

# %%
df2.groupby(['manufacturer']).mean()['mpg']
# This is the mean
# Out:
# manufacturer
# amc              18.070370
# audi             26.714286
# bmw              23.750000
# buick            19.182353
# cadillac         19.750000
# capri            25.000000
# chevroelt        16.000000
# chevrolet        20.472093
# chevy            18.000000
# chrysler         17.266667
# datsun           31.113043
# dodge            22.060714
# fiat             28.912500
# ford             19.475000
# hi                9.000000
# honda            33.761538
# maxda            26.050000
# mazda            30.860000
# mercedes         25.400000
# mercedes-benz    23.250000
# mercury          19.118182
# nissan           36.000000
# oldsmobile       21.100000
# opel             25.750000
# peugeot          23.687500
# plymouth         21.703226
# pontiac          20.012500
# renault          29.666667
# saab             23.900000
# subaru           30.525000
# toyota           28.372000
# toyouta          23.000000
# triumph          35.000000
# vokswagen        29.800000
# volkswagen       29.106667
# volvo            21.116667
# vw               39.016667
# Name: mpg, dtype: float64

# %%
saab_df2 = df2[df2['manufacturer'] == 'saab']
saab_df2
# Out:
#       mpg  cyl  displ   hp  weight  accel  yr  origin        name  \
# 22   25.0    4    104   95    2375   17.5  70       2    saab 99e
# 121  24.0    4    121  110    2660   14.0  73       2   saab 99le
# 178  25.0    4    121  115    2671   13.5  75       2   saab 99le
# 274  21.6    4    121  115    2795   15.7  78       2  saab 99gle
#
#     manufacturer  model
# 22          saab    99e
# 121         saab   99le
# 178         saab   99le
# 274         saab  99gle

# %%
saab_df2_plot = saab_df2.groupby('yr').mean()['mpg']
saab_df2_plot.plot()

# %%
audi_df2 = df2[df2['manufacturer'] == 'audi']
audi_df2
# Out:
#       mpg  cyl  displ   hp  weight  accel  yr  origin                 name  \
# 21   24.0    4    107   90    2430   14.5  70       2          audi 100 ls
# 118  20.0    4    114   91    2582   14.0  73       2           audi 100ls
# 139  29.0    4     98   83    2219   16.5  74       2             audi fox
# 175  23.0    4    115   95    2694   15.0  75       2           audi 100ls
# 272  20.3    5    131  103    2830   15.9  78       2            audi 5000
# 315  34.3    4     97   78    2188   15.8  80       2            audi 4000
# 325  36.4    5    121   67    2950   19.9  80       2  audi 5000s (diesel)
#
#     manufacturer           model
# 21          audi          100 ls
# 118         audi           100ls
# 139         audi             fox
# 175         audi           100ls
# 272         audi            5000
# 315         audi            4000
# 325         audi  5000s (diesel)

# %%
audi_df2_plot = audi_df2.groupby('yr').mean()['mpg']
audi_df2_plot.plot()

# %%
ford_df2 = df2[df2['manufacturer'] == 'ford']
ford_df2
# Out:
#       mpg  cyl  displ   hp  weight  accel  yr  origin  \
# 4    17.0    8    302  140    3449   10.5  70       1
# 5    15.0    8    429  198    4341   10.0  70       1
# 17   21.0    6    200   85    2587   16.0  70       1
# 25   10.0    8    360  215    4615   14.0  70       1
# 35   19.0    6    250   88    3302   15.5  71       1
# 39   14.0    8    351  153    4154   13.5  71       1
# 42   13.0    8    400  170    4746   12.0  71       1
# 47   18.0    6    250   88    3139   14.5  71       1
# 60   21.0    4    122   86    2226   16.5  72       1
# 64   14.0    8    351  153    4129   13.0  72       1
# 73   13.0    8    302  140    4294   16.0  72       1
# 79   22.0    4    122   86    2395   16.0  72       1
# 87   14.0    8    302  137    4042   14.5  73       1
# 91   13.0    8    351  158    4363   13.0  73       1
# 99   18.0    6    250   88    3021   16.5  73       1
# 103  12.0    8    400  167    4906   12.5  73       1
# 111  19.0    4    122   85    2310   18.5  73       1
# 128  26.0    4    122   80    2451   16.5  74       1
# 284           ford ltd landau         ford           ltd landau
# 288  ford country squire (sw)         ford  country squire (sw)
# 312             ford fairmont         ford             fairmont
# 347            ford escort 4w         ford            escort 4w
# 348            ford escort 2h         ford            escort 2h
# 360           ford granada gl         ford           granada gl
# 368      ford fairmont futura         ford      fairmont futura
# 383            ford granada l         ford            granada l
# 387           ford mustang gl         ford           mustang gl
# 390               ford ranger         ford               ranger

# %%
ford_df2_plot = ford_df2.groupby('yr').mean()['mpg']
ford_df2_plot.plot()

# %%
toyota_df2 = df2[df2['manufacturer'] == 'toyota']
toyota_df2
# Out:
#       mpg  cyl  displ   hp  weight  accel  yr  origin  \
# 14   24.0    4    113   95    2372   15.0  70       3
# 31   25.0    4    113   95    2228   14.0  71       3
# 52   31.0    4     71   65    1773   19.0  71       3
# 56   24.0    4    113   95    2278   15.5  72       3
# 83   27.0    4     97   88    2100   16.5  72       3
# 107  20.0    4     97   88    2279   19.0  73       3
# 122  20.0    6    156  122    2807   13.5  73       3
# 129  32.0    4     71   65    1836   21.0  74       3
# 142  31.0    4     76   52    1649   16.5  74       3
# 165  29.0    4     97   75    2171   16.0  75       3
# 169  24.0    4    134   96    2702   13.5  75       3
# 203  28.0    4     97   75    2155   16.4  76       3
# 208  19.0    6    156  108    2930   15.5  76       3
# 233  26.0    4     97   75    2265   18.2  77       3
# 265  27.5    4    134   95    2560   14.2  78       3
# 268  21.1    4    134   95    2515   14.8  78       3
# 308  38.1    4     89   60    1968   18.8  80       3
# 316  29.8    4    134   90    2711   15.5  80       3
# 319  32.2    4    108   75    2265   15.2  80       3
# 339  39.1    4     79   58    1755   16.9  81       3
# 344  37.7    4     89   62    2050   17.3  81       3
# 351  32.4    4    108   75    2350   16.8  81       3
# 356  25.4    6    168  116    2900   12.6  81       3
# 376  34.0    4    108   70    2245   16.9  82       3
# 384  32.0    4    144   96    2665   13.9  82       3
#
#                           name manufacturer               model
# 14       toyota corona mark ii       toyota      corona mark ii
# 31               toyota corona       toyota              corona
# 52         toyota corolla 1200       toyota        corolla 1200
# 56       toyota corona hardtop       toyota      corona hardtop
# 83    toyota corolla 1600 (sw)       toyota   corolla 1600 (sw)
# 107              toyota carina       toyota              carina
# 122             toyota mark ii       toyota             mark ii
# 129        toyota corolla 1200       toyota        corolla 1200
# 142              toyota corona       toyota              corona
# 165             toyota corolla       toyota             corolla
# 169              toyota corona       toyota              corona
# 203             toyota corolla       toyota             corolla
# 208             toyota mark ii       toyota             mark ii
# 233    toyota corolla liftback       toyota    corolla liftback
# 265              toyota corona       toyota              corona
# 268  toyota celica gt liftback       toyota  celica gt liftback
# 308      toyota corolla tercel       toyota      corolla tercel
# 316     toyota corona liftback       toyota     corona liftback
# 319             toyota corolla       toyota             corolla
# 339             toyota starlet       toyota             starlet
# 344              toyota tercel       toyota              tercel
# 351             toyota corolla       toyota             corolla
# 356            toyota cressida       toyota            cressida
# 376             toyota corolla       toyota             corolla
# 384           toyota celica gt       toyota           celica gt

# %%
toyota_df2_plot = toyota_df2.groupby('yr').mean()['mpg']
toyota_df2_plot.plot()
